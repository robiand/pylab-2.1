# %%
import rectangle as Rectangle
import circle as Circle

rectangle1 = Rectangle(0, 0, 5, 4)
rectangle2 = Rectangle(0.4, 0.5, 7)

circle1 = Circle(0, 0, 7.2)
circle1
# Out:
# Running cells with 'pylab-2 (Python 3.12.10)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: 'c:/Users/ander/Documents/github/pylab-2/.venv/Scripts/python.exe -m pip install ipykernel -U --force-reinstall'
