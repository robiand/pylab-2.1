# %%
from rectangle import Rectangle
from circle import Circle

rectangle1 = Rectangle(0, 0, 5, 4)
rectangle2 = Rectangle(0.4, 0.5, 7, 2)

#translate rectangle after creation to give x and y pos a non-0 value
rectangle1.translate(0.5, 3)
rectangle1.y

#compare rectangles
rectangle1 == rectangle2

print(rectangle1)

circle1 = Circle(0, 0, 7.2)
circle1.translate(2, 0.2)

circle2 = Circle(0, 1, 7.5)
circle2 == circle1
#test shape with incorrect params to test return value
#circle2 = Circle(1)

#circle1.translate(1, 2)
# Out:
# False
# Shape with coordinates: 0.5, 3
# False
