# %%
import rectangle as Rectangle
import circle as Circle

rectangle1 = Rectangle(0, 0, 5, 4)
rectangle2 = Rectangle(0.4, 0.5, 7)

rectangle1 == rectangle2

#circle1 = Circle(0, 0, 7.2)
#circle1.translate(1, 2)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import rectangle as Rectangle
#       2 import circle as Circle
#       4 rectangle1 = Rectangle(0, 0, 5, 4)
#
# File c:\Users\ander\Documents\github\pylab-2\rectangle.py:1
# ----> 1 from shape import Shape
#       3 class rectangle:
#       4     def __init__(self, x: int | float, y: int | float, width: int | float, height: int | float):
#
# ImportError: cannot import name 'Shape' from 'shape' (c:\Users\ander\Documents\github\pylab-2\shape.py)
